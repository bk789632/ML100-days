# %% [markdown]
# 1. 我選了kaggle 競賽上 Two Sigma: Using News to Predict Stock Movements 這組題目
#    財務金融一直是大數據上熱門的行業，除了傳統的看k線，我們還可以透過什麼去預測？
#    是不是有很多股票操作，都透過媒體去傳遞一些訊息？
# 2.由Intrinio提供市場數據。
# 新聞數據資料來源：湯森路透 - 包含有關資產的新聞文章警報信息，如文章詳情，情緒和其他評論。
# 3.股票數據為 結構數據。
#    新聞報導為 非結構數據。
# 4. 回歸分析 、 時間序列分析。

# %% [markdown]
# 1.我想以乘客體驗來提升業績
# 2. 以每次乘客問卷回答取得數據 或 網路聲量的數據。
# 3.非結構化數據
# 4.使用跑出來的資訊， 對比過去做回測。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))


w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()
# Out:
# The Mean absolute error is 12.258

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-6c6421c9745f> in <module>()
# ----> 1 MSE = mean_squared_error(y, y_hat)
#       2 MAE = mean_absolute_error(y, y_hat)
#       3 print("The Mean squared error is %.3f" % (MSE))
#       4 print("The Mean absolute error is %.3f" % (MAE))
#
# TypeError: mean_squared_error() takes 0 positional arguments but 2 were given
